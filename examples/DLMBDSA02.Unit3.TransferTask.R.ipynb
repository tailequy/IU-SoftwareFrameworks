# %%
#If-else statement
a <- 200
b <- 33

if (b > a) {
  print("b is greater than a")
} else if (a == b) {
  print("a and b are equal")
} else {
  print("a is greater than b")
}
# Out:
# [1] "a is greater than b"

# %%
#While loop statement
i <- 1
while (i < 6) {
  print(i)
  i <- i + 1
  if (i == 4) {
    break
  }
}
# Out:
# [1] 1
# [1] 2
# [1] 3

# %%
#For loop
fruits <- list("apple", "banana", "cherry")

for (x in fruits) {
  print(x)
}
# Out:
# [1] "apple"
# [1] "banana"
# [1] "cherry"

# %%
#Mean function
meanval <- function(x) {
  return(sum(x)/length(x))
}

x <- c(1,2,3,4,5)
print(meanval(x))
# Out:
# [1] 3

# %%
#Library
library(MASS)
painters
# Out:
#                 Composition Drawing Colour Expression School
# Da Udine        10           8      16      3         A
# Da Vinci        15          16       4     14         A
# Del Piombo       8          13      16      7         A
# Del Sarto       12          16       9      8         A
# Fr. Penni        0          15       8      0         A
# Guilio Romano   15          16       4     14         A
# Michelangelo     8          17       4      8         A
# Perino del Vaga 15          16       7      6         A
# Perugino         4          12      10      4         A
# Raphael         17          18      12     18         A
# F. Zucarro      10          13       8      8         B
# Fr. Salviata    13          15       8      8         B
# Parmigiano      10          15       6      6         B
# Primaticcio     15          14       7     10         B
# T. Zucarro      13          14      10      9         B
# Volterra        12          15       5      8         B
# ...

# %%
school = painters$School
Composition = painters$Composition
Drawing = painters$Drawing
Color = painters$Colour
Expression = painters$Expression

# %%
school.fred = table(school)
school.fred
# Out:
# school
#  A  B  C  D  E  F  G  H
# 10  6  6 10  7  4  7  4

# %%
#Bar chart
barplot(school.fred)
# Out:
# plot without title

# %%
#Pie chart
pie(school.fred)
# Out:
# plot without title

# %%
#Box plot
boxplot(painters$Composition)
# Out:
# plot without title

# %%
#Scatter plot
plot(Composition[1:15],Drawing[1:15],xlab = "Composition",ylab="Drawing")
# Out:
# plot without title

# %%
#Basic statistic, compute the mean of the composition variable for the painters of school "C"
c_school = school == "C"
c_painters = painters[c_school,]
mean(c_painters$Composition)
# Out:
# [1] 13.16667

# %%
#calculate the mean of the composition variable for each schoo
tapply (Composition, school, mean)
# Out:
#        A        B        C        D        E        F        G        H
# 10.40000 12.16667 13.16667  9.10000 13.57143  7.25000 13.85714 14.00000

# %%
# Add a Normal Curve
x <- painters$Composition
h<-hist(x, breaks=10, col="red", xlab="Compostion",
   main="Histogram with Normal Curve")
xfit<-seq(min(x),max(x),length=40)
yfit<-dnorm(xfit,mean=mean(x),sd=sd(x))
yfit <- yfit*diff(h$mids[1:2])*length(x)

lines(xfit, yfit, col="blue", lwd=2)
# Out:
# Plot with title “Histogram with Normal Curve”
